# %%
print("This notebook is designed to fail.")
# Out:
# This notebook is designed to fail.

# %%
raise Exception("Intentional Failure for Testing")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 raise Exception("Intentional Failure for Testing")
#
# Exception: Intentional Failure for Testing
