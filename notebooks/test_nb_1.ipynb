# %%
import time
print("Starting Notebook 1")
time.sleep(2)
print("Finished Notebook 1")
# Out:
# Starting Notebook 1
# Finished Notebook 1

# %%
import time
print("Starting Notebook 1 Cell2")
time.sleep(2)
print("Finished Notebook 1 Cell2")
# Out:
# Starting Notebook 1 Cell2
# Finished Notebook 1 Cell2
